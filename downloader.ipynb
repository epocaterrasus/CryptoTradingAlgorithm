# %% [markdown]
# # DATA DOWNLOADER

# %%
# import libraries
import pandas as pd
import requests
import os
import time
from datetime import datetime,timedelta,timezone
from utils import try_request
import json

# %%
coin_pair = 'btc-usdt'
days_back = 1095
freq = '1day'

now = datetime.utcnow() # get current date and time in UTC
today_normal = now.replace(tzinfo = timezone.utc)  # set UTC the timezone 
begin_normal = today_normal - timedelta(days=days_back)

begin_unix = int(begin_normal.timestamp())
end_unix = int(today_normal.timestamp())

print(begin_unix)
print(end_unix)
# Out:
# 1554642954
# 1649250954

# %%
base_format = 'https://api.kucoin.com/api/v1/market/candles?symbol={}&type={}&startAt={}&endAt={}'

# %%
"""[
    [
        "1545904980",             //Start time of the candle cycle
        "0.058",                  //opening price
        "0.049",                  //closing price
        "0.058",                  //highest price
        "0.049",                  //lowest price
        "0.018",                  //Transaction volume
        "0.000945"                //Transaction amount
    ],
    """
web_page = base_format.format(
    coin_pair.upper(),
    freq,
    begin_unix,
    end_unix
)
web_page
# Out:
# 'https://api.kucoin.com/api/v1/market/candles?symbol=BTC-USDT&type=1day&startAt=1554642954&endAt=1649250954'

# %%
resp = try_request(web_page)
resp = resp.json()
#print(json.dumps(resp, indent=4, sort_keys=True))
data = resp['data']

# %%
df = pd.DataFrame(
    data,
    columns=['date','open','close','high','low','volume','amount'],
)

df = df.iloc[::-1]
df.index = df['date']
df
# Out:
#                   date     open    close     high      low          volume  \
# date
# 1554681600  1554681600     5166     5236     5300   5039.9    567.18077645
# 1554768000  1554768000     5241   5143.5     5241   5080.9    533.91069255
# 1554854400  1554854400   5143.5   5305.7     5400   5130.9    484.59675085
# 1554940800  1554940800   5307.6     5016   5332.4   4926.4    466.73618209
# 1555027200  1555027200     5018   5050.6     5075   4873.8     247.7584872
# ...                ...      ...      ...      ...      ...             ...
# 1648857600  1648857600  46283.9  45806.6    47198  45610.4  30193.59439199
# 1648944000  1648944000  45806.6  46414.5    47476    45534     24653.42246
# 1649030400  1649030400  46414.6  46584.1  46884.6  45080.4  36537.81649675
# 1649116800  1649116800  46584.1    45501    47193    45358  14414.36282133
# 1649203200  1649203200    45501  44910.4  45506.4    44421  10442.21900247
#
#                           amount
# date
# 1554681600     2932448.283171606
# 1554768000     2751033.295967874
# 1554854400     2545518.965912749
# 1554940800     2370637.204087437
# 1555027200     1240250.485928189
# ...                          ...
# 1648857600  1402187503.542836981
# 1648944000  1143632545.226320617
# 1649030400  1679316938.304057504
# 1649116800   666630593.837973305
# 1649203200   471480353.050791231
#
# [1095 rows x 7 columns]

# %%
df.iloc[::-1]
# Out:
#             date     open    close     high      low          volume  \
# 1094  1554681600     5166     5236     5300   5039.9    567.18077645
# 1093  1554768000     5241   5143.5     5241   5080.9    533.91069255
# 1092  1554854400   5143.5   5305.7     5400   5130.9    484.59675085
# 1091  1554940800   5307.6     5016   5332.4   4926.4    466.73618209
# 1090  1555027200     5018   5050.6     5075   4873.8     247.7584872
# ...          ...      ...      ...      ...      ...             ...
# 4     1648857600  46283.9  45806.6    47198  45610.4  30193.59439199
# 3     1648944000  45806.6  46414.5    47476    45534     24653.42246
# 2     1649030400  46414.6  46584.1  46884.6  45080.4  36537.81649675
# 1     1649116800  46584.1    45501    47193    45358  14414.36282133
# 0     1649203200    45501  44910.4  45506.4    44421  10442.21900247
#
#                     amount
# 1094     2932448.283171606
# 1093     2751033.295967874
# 1092     2545518.965912749
# 1091     2370637.204087437
# 1090     1240250.485928189
# ...                    ...
# 4     1402187503.542836981
# 3     1143632545.226320617
# 2     1679316938.304057504
# 1      666630593.837973305
# 0      471480353.050791231
#
# [1095 rows x 7 columns]
